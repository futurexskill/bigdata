# %%
orders_from_volume = spark.read.option("header", "true").csv("/Volumes/workspace/default/raw_data/ecommerce_messy_data.csv")

# %%
display(orders_from_volume)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
orders_from_volume.count()
# Out:
# 20

# %%
orders_from_volume.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- total_amount: string (nullable = true)

# %%
processed_orders = orders_from_volume.select("order_id", "product_name", "total_amount")

# %%
display(processed_orders)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
processed_orders.write.mode("overwrite").option("header", "true").csv("/Volumes/workspace/default/raw_data/processed_orders")

# %%
processed_orders.write.mode("overwrite").parquet("/Volumes/workspace/default/raw_data/processed_orders.parquet")

# %%
# %fs ls /Volumes/workspace/default/raw_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/default/raw_data/ecommerce_messy_data.csv</td><td>ecommerce_messy_data.csv</td><td>1120</td><td>1765892195000</td></tr><tr><td>dbfs:/Volumes/workspace/default/raw_data/processed_orders/</td><td>processed_orders/</td><td>0</td><td>1765892721308</td></tr><tr><td>dbfs:/Volumes/workspace/default/raw_data/processed_orders.parquet/</td><td>processed_orders.parquet/</td><td>0</td><td>1765892721308</td></tr></tbody></table></div>

# %%
parquet_data = spark.read.parquet("/Volumes/workspace/default/raw_data/processed_orders.parquet")
display(parquet_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.ls("/Volumes/workspace/default/raw_data")
# Out:
# [FileInfo(path='dbfs:/Volumes/workspace/default/raw_data/ecommerce_messy_data.csv', name='ecommerce_messy_data.csv', size=1120, modificationTime=1765892195000),
#  FileInfo(path='dbfs:/Volumes/workspace/default/raw_data/processed_orders/', name='processed_orders/', size=0, modificationTime=1765892820614),
#  FileInfo(path='dbfs:/Volumes/workspace/default/raw_data/processed_orders.parquet/', name='processed_orders.parquet/', size=0, modificationTime=1765892820614)]

# %%
# %fs head /Volumes/workspace/default/raw_data/ecommerce_messy_data.csv
# Out:
# order_id,product_name,category,country,payment_method,total_amount
# 001,LAPTOP_PRO ,Electronics,USA,Credit Card,1299.99
# 002,office chair,Furniture,Canada,Debit Card,299.50
# 003, wireless_Mouse,Electronics,UK,PayPal,49.99
# 004,DESK_LAMP,Furniture,USA,Credit Card,79.99
# 005,notebook_SET ,Stationery,Germany,Bank Transfer,29.99
# 006,USB Cable,Accessories,France,PayPal,15.99
# 007,mechanical_KEYBOARD,Electronics,Australia,Debit Card,159.99
# 008, MONITOR_4K,Electronics,India,Credit Card,599.99
# 009,ergonomic_CHAIR ,Furniture,Canada,PayPal,449.99
# 010,wireless HEADPHONES,Electronics,USA,Credit Card,199.99
# 011, PRINTER_INK,Accessories,UK,Debit Card,39.99
# 012,standing_desk,Furniture,Germany,Bank Transfer,599.00
# 013,NOTEBOOK_PACK ,Stationery,France,Credit Card,19.99
# 014, tablet_stand,Accessories,Australia,PayPal,34.99
# 015,WEBCAM_HD,Electronics,India,Credit Card,89.99
# 016,desk_ORGANIZER ,Accessories,USA,Debit Card,24.99
# 017, LAPTOP_BAG,Accessories,Canada,PayPal,79.99
# ...
