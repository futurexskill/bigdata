# %%
spark

# %%
orders_df = spark.sql("SELECT * FROM workspace.default.ecommerce_messy_data")

# %%
orders_df.show()
# Out:
# +--------+-------------------+-----------+---------+--------------+------------+
# |order_id|       product_name|   category|  country|payment_method|total_amount|
# +--------+-------------------+-----------+---------+--------------+------------+
# |       1|        LAPTOP_PRO |Electronics|      USA|   Credit Card|     1299.99|
# |       2|       office chair|  Furniture|   Canada|    Debit Card|       299.5|
# |       3|     wireless_Mouse|Electronics|       UK|        PayPal|       49.99|
# |       4|          DESK_LAMP|  Furniture|      USA|   Credit Card|       79.99|
# |       5|      notebook_SET | Stationery|  Germany| Bank Transfer|       29.99|
# |       6|          USB Cable|Accessories|   France|        PayPal|       15.99|
# |       7|mechanical_KEYBOARD|Electronics|Australia|    Debit Card|      159.99|
# |       8|         MONITOR_4K|Electronics|    India|   Credit Card|      599.99|
# |       9|   ergonomic_CHAIR |  Furniture|   Canada|        PayPal|      449.99|
# |      10|wireless HEADPHONES|Electronics|      USA|   Credit Card|      199.99|
# |      11|        PRINTER_INK|Accessories|       UK|    Debit Card|       39.99|
# |      12|      standing_desk|  Furniture|  Germany| Bank Transfer|       599.0|
# |      13|     NOTEBOOK_PACK | Stationery|   France|   Credit Card|       19.99|
# |      14|       tablet_stand|Accessories|Australia|        PayPal|       34.99|
# |      15|          WEBCAM_HD|Electronics|    India|   Credit Card|       89.99|
# |      16|    desk_ORGANIZER |Accessories|      USA|    Debit Card|       24.99|
# |      17|         LAPTOP_BAG|Accessories|   Canada|        PayPal|       79.99|
# |      18|      monitor_STAND|  Furniture|       UK|   Credit Card|      149.99|
# |      19|  WIRELESS_CHARGER |Electronics|  Germany| Bank Transfer|       44.99|
# |      20|            pen_SET| Stationery|   France|    Debit Card|       12.99|
# +--------+-------------------+-----------+---------+--------------+------------+

# %%
display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_name</th><th>category</th><th>country</th><th>payment_method</th><th>total_amount</th></tr></thead><tbody><tr><td>1</td><td>LAPTOP_PRO </td><td>Electronics</td><td>USA</td><td>Credit Card</td><td>1299.99</td></tr><tr><td>2</td><td>office chair</td><td>Furniture</td><td>Canada</td><td>Debit Card</td><td>299.5</td></tr><tr><td>3</td><td> wireless_Mouse</td><td>Electronics</td><td>UK</td><td>PayPal</td><td>49.99</td></tr><tr><td>4</td><td>DESK_LAMP</td><td>Furniture</td><td>USA</td><td>Credit Card</td><td>79.99</td></tr><tr><td>5</td><td>notebook_SET </td><td>Stationery</td><td>Germany</td><td>Bank Transfer</td><td>29.99</td></tr><tr><td>6</td><td>USB Cable</td><td>Accessories</td><td>France</td><td>PayPal</td><td>15.99</td></tr><tr><td>7</td><td>mechanical_KEYBOARD</td><td>Electronics</td><td>Australia</td><td>Debit Card</td><td>159.99</td></tr><tr><td>8</td><td> MONITOR_4K</td><td>Electronics</td><td>India</td><td>Credit Card</td><td>599.99</td></tr><tr><td>9</td><td>ergonomic_CHAIR </td><td>Furniture</td><td>Canada</td><td>PayPal</td><td>449.99</td></tr><tr><td>10</td><td>wireless HEADPHONES</td><td>Electronics</td><td>USA</td><td>Credit Card</td><td>199.99</td></tr><tr><td>11</td><td> PRINTER_INK</td><td>Accessories</td><td>UK</td><td>Debit Card</td><td>39.99</td></tr><tr><td>12</td><td>standing_desk</td><td>Furniture</td><td>Germany</td><td>Bank Transfer</td><td>599.0</td></tr><tr><td>13</td><td>NOTEBOOK_PACK </td><td>Stationery</td><td>France</td><td>Credit Card</td><td>19.99</td></tr><tr><td>14</td><td> tablet_stand</td><td>Accessories</td><td>Australia</td><td>PayPal</td><td>34.99</td></tr><tr><td>15</td><td>WEBCAM_HD</td><td>Electronics</td><td>India</td><td>Credit Card</td><td>89.99</td></tr><tr><td>16</td><td>desk_ORGANIZER </td><td>Accessories</td><td>USA</td><td>Debit Card</td><td>24.99</td></tr><tr><td>17</td><td> LAPTOP_BAG</td><td>Accessories</td><td>Canada</td><td>PayPal</td><td>79.99</td></tr><tr><td>18</td><td>monitor_STAND</td><td>Furniture</td><td>UK</td><td>Credit Card</td><td>149.99</td></tr><tr><td>19</td><td>WIRELESS_CHARGER </td><td>Electronics</td><td>Germany</td><td>Bank Transfer</td><td>44.99</td></tr><tr><td>20</td><td>pen_SET</td><td>Stationery</td><td>France</td><td>Debit Card</td><td>12.99</td></tr></tbody></table></div>

# %%
orders_df.printSchema()
# Out:
# root
#  |-- order_id: long (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- total_amount: double (nullable = true)

# %%
orders_df.count()
# Out:
# 20

# %%
# ============================================
# CELL 5: Transform - Trim spaces from product_name
# ============================================
# Narration: "Now let's do a simple transformation"
# "We'll clean product names by removing leading and trailing spaces"

from pyspark.sql.functions import trim, col

cleaned_df = orders_df.withColumn("product_name", trim(col("product_name")))

# %%
display(cleaned_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_name</th><th>category</th><th>country</th><th>payment_method</th><th>total_amount</th></tr></thead><tbody><tr><td>1</td><td>LAPTOP_PRO</td><td>Electronics</td><td>USA</td><td>Credit Card</td><td>1299.99</td></tr><tr><td>2</td><td>office chair</td><td>Furniture</td><td>Canada</td><td>Debit Card</td><td>299.5</td></tr><tr><td>3</td><td>wireless_Mouse</td><td>Electronics</td><td>UK</td><td>PayPal</td><td>49.99</td></tr><tr><td>4</td><td>DESK_LAMP</td><td>Furniture</td><td>USA</td><td>Credit Card</td><td>79.99</td></tr><tr><td>5</td><td>notebook_SET</td><td>Stationery</td><td>Germany</td><td>Bank Transfer</td><td>29.99</td></tr><tr><td>6</td><td>USB Cable</td><td>Accessories</td><td>France</td><td>PayPal</td><td>15.99</td></tr><tr><td>7</td><td>mechanical_KEYBOARD</td><td>Electronics</td><td>Australia</td><td>Debit Card</td><td>159.99</td></tr><tr><td>8</td><td>MONITOR_4K</td><td>Electronics</td><td>India</td><td>Credit Card</td><td>599.99</td></tr><tr><td>9</td><td>ergonomic_CHAIR</td><td>Furniture</td><td>Canada</td><td>PayPal</td><td>449.99</td></tr><tr><td>10</td><td>wireless HEADPHONES</td><td>Electronics</td><td>USA</td><td>Credit Card</td><td>199.99</td></tr><tr><td>11</td><td>PRINTER_INK</td><td>Accessories</td><td>UK</td><td>Debit Card</td><td>39.99</td></tr><tr><td>12</td><td>standing_desk</td><td>Furniture</td><td>Germany</td><td>Bank Transfer</td><td>599.0</td></tr><tr><td>13</td><td>NOTEBOOK_PACK</td><td>Stationery</td><td>France</td><td>Credit Card</td><td>19.99</td></tr><tr><td>14</td><td>tablet_stand</td><td>Accessories</td><td>Australia</td><td>PayPal</td><td>34.99</td></tr><tr><td>15</td><td>WEBCAM_HD</td><td>Electronics</td><td>India</td><td>Credit Card</td><td>89.99</td></tr><tr><td>16</td><td>desk_ORGANIZER</td><td>Accessories</td><td>USA</td><td>Debit Card</td><td>24.99</td></tr><tr><td>17</td><td>LAPTOP_BAG</td><td>Accessories</td><td>Canada</td><td>PayPal</td><td>79.99</td></tr><tr><td>18</td><td>monitor_STAND</td><td>Furniture</td><td>UK</td><td>Credit Card</td><td>149.99</td></tr><tr><td>19</td><td>WIRELESS_CHARGER</td><td>Electronics</td><td>Germany</td><td>Bank Transfer</td><td>44.99</td></tr><tr><td>20</td><td>pen_SET</td><td>Stationery</td><td>France</td><td>Debit Card</td><td>12.99</td></tr></tbody></table></div>

# %%
# ============================================
# CELL 7: Write cleaned data to new Delta Table
# ============================================
# Narration: "Now let's save this cleaned data as a new Delta Table"

cleaned_df.write.mode('overwrite').format('delta').saveAsTable("ecommerce_cleaned")

# %%
# ============================================
# CELL 8: Query the new cleaned table
# ============================================
# Narration: "Let's query the new cleaned table"

display(spark.sql("SELECT * FROM workspace.default.ecommerce_cleaned"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_name</th><th>category</th><th>country</th><th>payment_method</th><th>total_amount</th></tr></thead><tbody><tr><td>1</td><td>LAPTOP_PRO</td><td>Electronics</td><td>USA</td><td>Credit Card</td><td>1299.99</td></tr><tr><td>2</td><td>office chair</td><td>Furniture</td><td>Canada</td><td>Debit Card</td><td>299.5</td></tr><tr><td>3</td><td>wireless_Mouse</td><td>Electronics</td><td>UK</td><td>PayPal</td><td>49.99</td></tr><tr><td>4</td><td>DESK_LAMP</td><td>Furniture</td><td>USA</td><td>Credit Card</td><td>79.99</td></tr><tr><td>5</td><td>notebook_SET</td><td>Stationery</td><td>Germany</td><td>Bank Transfer</td><td>29.99</td></tr><tr><td>6</td><td>USB Cable</td><td>Accessories</td><td>France</td><td>PayPal</td><td>15.99</td></tr><tr><td>7</td><td>mechanical_KEYBOARD</td><td>Electronics</td><td>Australia</td><td>Debit Card</td><td>159.99</td></tr><tr><td>8</td><td>MONITOR_4K</td><td>Electronics</td><td>India</td><td>Credit Card</td><td>599.99</td></tr><tr><td>9</td><td>ergonomic_CHAIR</td><td>Furniture</td><td>Canada</td><td>PayPal</td><td>449.99</td></tr><tr><td>10</td><td>wireless HEADPHONES</td><td>Electronics</td><td>USA</td><td>Credit Card</td><td>199.99</td></tr><tr><td>11</td><td>PRINTER_INK</td><td>Accessories</td><td>UK</td><td>Debit Card</td><td>39.99</td></tr><tr><td>12</td><td>standing_desk</td><td>Furniture</td><td>Germany</td><td>Bank Transfer</td><td>599.0</td></tr><tr><td>13</td><td>NOTEBOOK_PACK</td><td>Stationery</td><td>France</td><td>Credit Card</td><td>19.99</td></tr><tr><td>14</td><td>tablet_stand</td><td>Accessories</td><td>Australia</td><td>PayPal</td><td>34.99</td></tr><tr><td>15</td><td>WEBCAM_HD</td><td>Electronics</td><td>India</td><td>Credit Card</td><td>89.99</td></tr><tr><td>16</td><td>desk_ORGANIZER</td><td>Accessories</td><td>USA</td><td>Debit Card</td><td>24.99</td></tr><tr><td>17</td><td>LAPTOP_BAG</td><td>Accessories</td><td>Canada</td><td>PayPal</td><td>79.99</td></tr><tr><td>18</td><td>monitor_STAND</td><td>Furniture</td><td>UK</td><td>Credit Card</td><td>149.99</td></tr><tr><td>19</td><td>WIRELESS_CHARGER</td><td>Electronics</td><td>Germany</td><td>Bank Transfer</td><td>44.99</td></tr><tr><td>20</td><td>pen_SET</td><td>Stationery</td><td>France</td><td>Debit Card</td><td>12.99</td></tr></tbody></table></div>

# %%
# ============================================
# CELL 9: Compare original vs cleaned (side by side)
# ============================================
# Narration: "Let's compare the original and cleaned product names"

print("ORIGINAL DATA:")
display(orders_df.select("order_id", "product_name"))

print("\nCLEANED DATA:")
display(cleaned_df.select("order_id", "product_name"))
# Out:
# ORIGINAL DATA:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_name</th></tr></thead><tbody><tr><td>1</td><td>LAPTOP_PRO </td></tr><tr><td>2</td><td>office chair</td></tr><tr><td>3</td><td> wireless_Mouse</td></tr><tr><td>4</td><td>DESK_LAMP</td></tr><tr><td>5</td><td>notebook_SET </td></tr><tr><td>6</td><td>USB Cable</td></tr><tr><td>7</td><td>mechanical_KEYBOARD</td></tr><tr><td>8</td><td> MONITOR_4K</td></tr><tr><td>9</td><td>ergonomic_CHAIR </td></tr><tr><td>10</td><td>wireless HEADPHONES</td></tr><tr><td>11</td><td> PRINTER_INK</td></tr><tr><td>12</td><td>standing_desk</td></tr><tr><td>13</td><td>NOTEBOOK_PACK </td></tr><tr><td>14</td><td> tablet_stand</td></tr><tr><td>15</td><td>WEBCAM_HD</td></tr><tr><td>16</td><td>desk_ORGANIZER </td></tr><tr><td>17</td><td> LAPTOP_BAG</td></tr><tr><td>18</td><td>monitor_STAND</td></tr><tr><td>19</td><td>WIRELESS_CHARGER </td></tr><tr><td>20</td><td>pen_SET</td></tr></tbody></table></div>
# CLEANED DATA:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_name</th></tr></thead><tbody><tr><td>1</td><td>LAPTOP_PRO</td></tr><tr><td>2</td><td>office chair</td></tr><tr><td>3</td><td>wireless_Mouse</td></tr><tr><td>4</td><td>DESK_LAMP</td></tr><tr><td>5</td><td>notebook_SET</td></tr><tr><td>6</td><td>USB Cable</td></tr><tr><td>7</td><td>mechanical_KEYBOARD</td></tr><tr><td>8</td><td>MONITOR_4K</td></tr><tr><td>9</td><td>ergonomic_CHAIR</td></tr><tr><td>10</td><td>wireless HEADPHONES</td></tr><tr><td>11</td><td>PRINTER_INK</td></tr><tr><td>12</td><td>standing_desk</td></tr><tr><td>13</td><td>NOTEBOOK_PACK</td></tr><tr><td>14</td><td>tablet_stand</td></tr><tr><td>15</td><td>WEBCAM_HD</td></tr><tr><td>16</td><td>desk_ORGANIZER</td></tr><tr><td>17</td><td>LAPTOP_BAG</td></tr><tr><td>18</td><td>monitor_STAND</td></tr><tr><td>19</td><td>WIRELESS_CHARGER</td></tr><tr><td>20</td><td>pen_SET</td></tr></tbody></table></div>

# %%
# ============================================
# CELL 10 (Optional): Show specific examples of trimming
# ============================================
# Narration: "Let's see specific examples where trimming made a difference"

from pyspark.sql.functions import length, concat, lit

display(
    orders_df.select(
        "order_id",
        concat(lit("["), col("product_name"), lit("]")).alias("original_with_brackets"),
        length("product_name").alias("original_length")
    ).join(
        cleaned_df.select(
            "order_id",
            concat(lit("["), col("product_name"), lit("]")).alias("cleaned_with_brackets"),
            length("product_name").alias("cleaned_length")
        ),
        "order_id"
    ).filter(col("original_length") != col("cleaned_length"))
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>original_with_brackets</th><th>original_length</th><th>cleaned_with_brackets</th><th>cleaned_length</th></tr></thead><tbody><tr><td>1</td><td>[LAPTOP_PRO ]</td><td>11</td><td>[LAPTOP_PRO]</td><td>10</td></tr><tr><td>3</td><td>[ wireless_Mouse]</td><td>15</td><td>[wireless_Mouse]</td><td>14</td></tr><tr><td>5</td><td>[notebook_SET ]</td><td>13</td><td>[notebook_SET]</td><td>12</td></tr><tr><td>8</td><td>[ MONITOR_4K]</td><td>11</td><td>[MONITOR_4K]</td><td>10</td></tr><tr><td>9</td><td>[ergonomic_CHAIR ]</td><td>16</td><td>[ergonomic_CHAIR]</td><td>15</td></tr><tr><td>11</td><td>[ PRINTER_INK]</td><td>12</td><td>[PRINTER_INK]</td><td>11</td></tr><tr><td>13</td><td>[NOTEBOOK_PACK ]</td><td>14</td><td>[NOTEBOOK_PACK]</td><td>13</td></tr><tr><td>14</td><td>[ tablet_stand]</td><td>13</td><td>[tablet_stand]</td><td>12</td></tr><tr><td>16</td><td>[desk_ORGANIZER ]</td><td>15</td><td>[desk_ORGANIZER]</td><td>14</td></tr><tr><td>17</td><td>[ LAPTOP_BAG]</td><td>11</td><td>[LAPTOP_BAG]</td><td>10</td></tr><tr><td>19</td><td>[WIRELESS_CHARGER ]</td><td>17</td><td>[WIRELESS_CHARGER]</td><td>16</td></tr></tbody></table></div>
